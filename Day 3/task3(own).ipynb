# %%
import pandas as pd
df = pd.read_csv('canada_per_capita_income.csv')
display(df.head())
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X=df[['year']]
y=df['per capita income (US$)']
model=LinearRegression()
model.fit(X,y)
score = model.score(X,y)
print(score)
year_2020=np.array([[2020]])
predicted_income_2020 = model.predict(year_2020)
print(f"Predicted per capita income for 2020: ${predicted_income_2020[0]:,.2f}")
# Out:
# 0.890916917957032
# Predicted per capita income for 2020: $41,288.69
# c:\Users\Amarnath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
