# %% [markdown]
# <a href="https://colab.research.google.com/github/Amar-7778/MLOPS-Task/blob/main/Task28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Different architectures to test
architectures = [
    [ 100 ],
    [ 200 ],
    [ 300 ],
    [ 100 , 50 ],
    [ 200 , 100 ],
    [ 300 , 150 ],
    [ 512 , 256 ],
    [ 512 , 256 , 128 ]
]

best_accuracy = 0
best_architecture = None

for arch in architectures:
    model = Sequential()
    model.add(Flatten(input_shape=( 28 , 28 )))

    for neurons in arch:
        model.add(Dense(neurons, activation= 'relu' ))

    model.add(Dense( 10 , activation= 'softmax' ))

    model.compile(
        optimizer= 'adam' ,
        loss= 'sparse_categorical_crossentropy' ,
        metrics=[ 'accuracy' ]
    )

    model.fit(X_train, y_train, epochs= 5 , verbose= 0 )

    loss, accuracy = model.evaluate(X_test, y_test, verbose= 0 )
    print ( f"Architecture {arch} -> Accuracy: {accuracy: .4f} " )

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_architecture = arch

print ( "\nBest Architecture:" , best_architecture)
print ( "Best Accuracy:" , best_accuracy)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Architecture [100] -> Accuracy:  0.9732
# Architecture [200] -> Accuracy:  0.9767
# Architecture [300] -> Accuracy:  0.9763
# Architecture [100, 50] -> Accuracy:  0.9763
# Architecture [200, 100] -> Accuracy:  0.9765
# Architecture [300, 150] -> Accuracy:  0.9805
# Architecture [512, 256] -> Accuracy:  0.9808
# Architecture [512, 256, 128] -> Accuracy:  0.9782
#
# Best Architecture: [512, 256]
# Best Accuracy: 0.9807999730110168
