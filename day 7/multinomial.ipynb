# %%
import pandas as pd
df=pd.read_excel("NarrateIQ_ML_Dataset.xlsx")
df.head()
# Out:
#   Student_ID Age_Group Disability_Type Severity_Level        State  \
# 0    STU1000     11-13          Autism           Mild           UP
# 1    STU1001       5-7        Multiple           Mild           UP
# 2    STU1002       5-7            ADHD           Mild    Karnataka
# 3    STU1003      8-10            ADHD           Mild  West Bengal
# 4    STU1004      8-10        Dyslexia           Mild      Gujarat
#
#       School_Type Language Teacher_Experience Input_Mode  Content_Format  ...  \
# 0  Special School    Hindi           5+ Years      Video  Animated Video  ...
# 1             NGO   Telugu          3-5 Years      Video      Text+Audio  ...
# 2      Government    Hindi          3-5 Years      Audio  Animated Video  ...
# 3      Government  English          1-3 Years       Text      ISL Avatar  ...
# 4      Government  Kannada          1-3 Years      Video  Animated Video  ...
#
#    Offline_Mode_Used  Device_Type  Parental_Involvement  Engagement_Score  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

target = 'Learning_Outcome'
feature_cols = [c for c in df.columns if c not in ['Student_ID', target]]

X = df[feature_cols].copy()
y = df[target]

categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

x_train, x_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=22, stratify=y
)

model = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_leaf=1,
    class_weight='balanced',
    random_state=32,
    n_jobs=-1
)

model.fit(x_train, y_train)
accuracy = model.score(x_test, y_test)
accuracy
# Out:
# 0.8666666666666667

# %%
def predict_learning_outcome(engagement_score, attention_span_min, disability_type):
    sample = pd.DataFrame([{
        'Disability_Type': disability_type,
        'Engagement_Score': engagement_score,
        'Attention_Span_Min': attention_span_min
    }])

    sample_encoded = pd.get_dummies(sample, columns=['Disability_Type'], drop_first=True)
    sample_encoded = sample_encoded.reindex(columns=X_small_encoded.columns, fill_value=0)

    return student_model.predict(sample_encoded)[0]


prediction = predict_learning_outcome(75, 12, 'Autism')
prediction
# Out:
# 'Average'
